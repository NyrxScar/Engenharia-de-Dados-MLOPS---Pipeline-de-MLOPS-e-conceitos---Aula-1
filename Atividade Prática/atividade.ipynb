# %% [markdown]
# 1. [Engenharia de Dados — Diagnóstico]: Explique detalhadamente por que a validação atual baseada em 'is not None' falhou em impedir a quebra do código ao processar o registro id: 102. Qual erro específico esse tipo de dado ocasionaria na fase de treinamento do modelo ?

# %% [markdown]
# 2. [Engenharia de Dados — Implementação]: Reescreva e teste o trecho de código em Python referente à etapa de sanitização/ETL (dados_limpos = ...) de forma a garantir que apenas registros com 'idade' e 'renda' válidos (numéricos e estritamente maiores que zero) sejam mantidos na base.

# %% [markdown]
# 3. [MLOps — Governança e Qualidade]: Suponha que, após aplicar o seu novo filtro em um lote de
# 1.000 clientes, 950 registros fossem descartados por corrupção de dados. Se os 50 registros restantes
# resultassem em uma acurácia simulada de 98%, o sistema de MLOps deveria aprovar esse modelo
# automaticamente para produção? Justifique sua resposta considerando boas práticas de governança,
# 'Data Drift' e monitoramento.
